# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm

# %% [markdown]
# ### Reading dataset file as a dataframe

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### Dataframe Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### Checking for missing values

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# #### There are no missing values for all the columns

# %% [markdown]
# ### Dataframe description

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ### Dropping redundant variables

# %%
df = df.drop(['id', 'lat', 'long'], axis = 1)
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# ### Correlation with Price and A Bar plot illustration

# %%
correlation = df.corr()['price'].sort_values(ascending=False)
correlation
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
plt.figure(figsize = (14,7))
Sorted_values = correlation.sort_values(ascending=False).plot(kind='bar')
plt.title("Correlated Bar Plot")
# Out:
# Text(0.5, 1.0, 'Correlated Bar Plot')

# %% [markdown]
# #### Sqft_living, grade,sqft_above, sqft_living15 and bathrooms have moderate to good correlation with price

# %% [markdown]
# ### Heatmap Showing Relationship Between Variables

# %%
plt.figure (figsize = (16,9))
sns.heatmap(df.corr(), vmin= -1, vmax= 1, cmap="Spectral", annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Scatter Plots Showing Variables(sqft_living, grade, sqft_above, sqft_living15, bathrooms) That Showed Moderate to Good Positive Relationship with Price

# %%
sns.relplot(x="sqft_living", y="price",data=df,kind="scatter")
plt.title("Scatter plot of Sqft_living against price")
plt.show()

# %%
sns.relplot(x="grade", y="price",data=df,kind="scatter")
plt.title("Scatter plot of grade against price")
plt.show()

# %%
sns.relplot(x="sqft_above", y="price",data=df,kind="scatter")
plt.title("Scatter plot of Sqft_above against price")
plt.show()

# %%
sns.relplot(x="sqft_living15", y="price",data=df,kind="scatter")
plt.title("Scatter plot of Sqft_living15 against price")
plt.show()

# %%
sns.relplot(x="bathrooms", y="price",data=df,kind="scatter")
plt.title("Scatter plot of Bathrooms against price")
plt.show()

# %%
#Showing the highest number of bathrooms houses
plt.figure(figsize = (10, 3), dpi = 100)
sns.countplot(x="bathrooms", data=df)
plt.show()

# %%
#Showing the highest number of bedrooms houses
plt.figure(figsize = (10, 5), dpi = 100)
sns.countplot(x="bedrooms", data=df)
plt.show()

# %%
#How does waterfront affect price
plt.figure(figsize=(8,4), dpi = 100)
sns.boxplot(x='waterfront',y='price',data=df)
plt.show()

# %%
#How does grade affect price
plt.figure(figsize=(8,4), dpi = 100)
sns.boxplot(x='grade',y='price',data=df)
plt.show()

# %%
#How does view affect price
plt.figure(figsize=(8,4), dpi = 100)
sns.boxplot(x='view',y='price',data=df)
plt.show()

# %%
#How does view affect price
plt.figure(figsize=(10,6), dpi = 100)
sns.boxplot(x='bathrooms',y='price',data=df)
plt.show()

# %%
sns.relplot(x="sqft_living", y="price", data=df, kind="scatter", col="waterfront")
plt.show()

# %% [markdown]
# ### Changing date type to Month and Year

# %%
df['date'] = pd.to_datetime(df['date'])
df['date'].head(15)
# Out:
# 0    2014-10-13
# 1    2014-12-09
# 2    2015-02-25
# 3    2014-12-09
# 4    2015-02-18
# 5    2014-05-12
# 6    2014-06-27
# 7    2015-01-15
# 8    2015-04-15
# 9    2015-03-12
# 10   2015-04-03
# 11   2014-05-27
# 12   2014-05-28
# 13   2014-10-07
# 14   2015-03-12
# Name: date, dtype: datetime64[ns]

# %%
df['date_year'] = df['date'].apply(lambda x: x.year)
df['date_month'] = df['date'].apply(lambda x: x.month)

# %% [markdown]
# ### Total Number of Houses sold in 2014 and 2015 with their respective Perecntages

# %%
total = df.date_year.value_counts()
percentage = df.date_year.value_counts(normalize =True)
print('The total number of houses sold in both years: \n', total)
print('The percentage of houses sold in both years: \n', percentage)
# Out:
# The total number of houses sold in both years:
#  2014    14633
# 2015     6980
# Name: date_year, dtype: int64
# The percentage of houses sold in both years:
#  2014    0.677046
# 2015    0.322954
# Name: date_year, dtype: float64

# %% [markdown]
# ### Checking Average Price by year(2014 - 2015) and Month

# %%
yearly_price = df.groupby('date_year').mean()['price']
yearly_price
# Out:
# date_year
# 2014    539181.428415
# 2015    541988.992264
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,4), dpi = 100)
monthly_price = df.groupby('date_month').mean()['price']
plt.title("Line plot of prices of houses sold per month")
monthly_price.plot()
# Out:
# <AxesSubplot:title={'center':'Line plot of prices of houses sold per month'}, xlabel='date_month'>

# %% [markdown]
# ### Calculating the Age of the House

# %%
df['yr_built'].head()
# Out:
# 0    1955
# 1    1951
# 2    1933
# 3    1965
# 4    1987
# Name: yr_built, dtype: int64

# %%
df['House_Age'] = df['date_year'] - df['yr_built']
df['House_Age'].head()
# Out:
# 0    59
# 1    63
# 2    82
# 3    49
# 4    28
# Name: House_Age, dtype: int64

# %%
df['House_Age'].min()
# Out:
# -1

# %%
df['House_Age'].max()
# Out:
# 115

# %%
df['House_Age'].mean()
# Out:
# 43.31781797991949

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %% [markdown]
# ### Using OLS Regression

# %%
independent_variables = df.columns
independent_variables
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_living15',
#        'sqft_lot15', 'date_year', 'date_month', 'House_Age'],
#       dtype='object')

# %%
independent_variables = df[['bedrooms', 'bathrooms',
       'floors', 'waterfront', 'view', 'condition', 'grade', 'House_Age']]
dependent_variable = df['price'] 
independent_variables = sm.add_constant(independent_variables)
regression_model = sm.OLS(dependent_variable,independent_variables).fit()
regression_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.609
# Model:                            OLS   Adj. R-squared:                  0.609
# Method:                 Least Squares   F-statistic:                     4204.
# Date:                Tue, 01 Mar 2022   Prob (F-statistic):               0.00
# Time:                        18:45:14   Log-Likelihood:            -2.9746e+05
# No. Observations:               21613   AIC:                         5.949e+05
# Df Residuals:                   21604   BIC:                         5.950e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.428e+06   1.61e+04    -88.776      0.000   -1.46e+06    -1.4e+06
# ...

# %%
#Coefficients that reacts strongly with respect to price
plt.figure(figsize=(10,6), dpi = 100)
regression_model.params.plot(kind='bar')
plt.title("Regressive Coefficients for Price")
# Out:
# Text(0.5, 1.0, 'Regressive Coefficients for Price')

# %%
#Prediction
df['Prediction'] = pd.DataFrame(regression_model.predict(independent_variables))
df['Prediction']
# Out:
# 0        313388.631454
# 1        495698.885817
# 2        221864.963272
# 3        555225.227189
# 4        495329.342750
#              ...
# 21608    484810.130494
# 21609    456678.848635
# 21610     70633.681948
# 21611    498164.205283
# 21612     74772.134904
# Name: Prediction, Length: 21613, dtype: float64
